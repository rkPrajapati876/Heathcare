# %%
import os
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\rkpra\Downloads\Healthcare provider fraud detection\archive\Train.csv")

# %%
df.head()
# Out:
#    Provider PotentialFraud
# 0  PRV51001             No
# 1  PRV51003            Yes
# 2  PRV51004             No
# 3  PRV51005            Yes
# 4  PRV51007             No

# %%
train_beneficial = pd.read_csv(r"C:\Users\rkpra\Downloads\Healthcare provider fraud detection\archive\Train_Beneficiarydata.csv")

# %%
train_beneficial
# Out:
#             BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  \
# 0        BENE11001  1943-01-01  NaN       1     1                     0
# 1        BENE11002  1936-09-01  NaN       2     1                     0
# 2        BENE11003  1936-08-01  NaN       1     1                     0
# 3        BENE11004  1922-07-01  NaN       1     1                     0
# 4        BENE11005  1935-09-01  NaN       1     1                     0
# ...            ...         ...  ...     ...   ...                   ...
# 138551  BENE159194  1939-07-01  NaN       1     1                     0
# 138552  BENE159195  1938-12-01  NaN       2     1                     0
# 138553  BENE159196  1916-06-01  NaN       2     1                     0
# 138554  BENE159197  1930-01-01  NaN       1     1                     0
# 138555  BENE159198  1952-04-01  NaN       2     1                     0
#
#         State  County  NoOfMonths_PartACov  NoOfMonths_PartBCov  \
# ...

# %%
pd.set_option('display.max_columns',500)

# %%
Train_Beneficial
# Out:
#             BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  \
# 0        BENE11001  1943-01-01  NaN       1     1                     0
# 1        BENE11002  1936-09-01  NaN       2     1                     0
# 2        BENE11003  1936-08-01  NaN       1     1                     0
# 3        BENE11004  1922-07-01  NaN       1     1                     0
# 4        BENE11005  1935-09-01  NaN       1     1                     0
# ...            ...         ...  ...     ...   ...                   ...
# 138551  BENE159194  1939-07-01  NaN       1     1                     0
# 138552  BENE159195  1938-12-01  NaN       2     1                     0
# 138553  BENE159196  1916-06-01  NaN       2     1                     0
# 138554  BENE159197  1930-01-01  NaN       1     1                     0
# 138555  BENE159198  1952-04-01  NaN       2     1                     0
#
#         State  County  NoOfMonths_PartACov  NoOfMonths_PartBCov  \
# ...

# %%
Train_Beneficial.head()
# Out:
#       BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  State  \
# 0  BENE11001  1943-01-01  NaN       1     1                     0     39
# 1  BENE11002  1936-09-01  NaN       2     1                     0     39
# 2  BENE11003  1936-08-01  NaN       1     1                     0     52
# 3  BENE11004  1922-07-01  NaN       1     1                     0     39
# 4  BENE11005  1935-09-01  NaN       1     1                     0     24
#
#    County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# 0     230                   12                   12                      1
# 1     280                   12                   12                      2
# 2     590                   12                   12                      1
# 3     270                   12                   12                      1
# 4     680                   12                   12                      2
#
# ...

# %%
Train_Beneficial.shape
# Out:
# (138556, 25)

# %%
Train_Beneficial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138556 entries, 0 to 138555
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   BeneID                           138556 non-null  object
#  1   DOB                              138556 non-null  object
#  2   DOD                              1421 non-null    object
#  3   Gender                           138556 non-null  int64
#  4   Race                             138556 non-null  int64
#  5   RenalDiseaseIndicator            138556 non-null  object
#  6   State                            138556 non-null  int64
#  7   County                           138556 non-null  int64
#  8   NoOfMonths_PartACov              138556 non-null  int64
#  9   NoOfMonths_PartBCov              138556 non-null  int64
#  10  ChronicCond_Alzheimer            138556 non-null  int64
# ...

# %%
train_InP = pd.read_csv(r"C:\Users\rkpra\Downloads\Healthcare provider fraud detection\archive\Train_Inpatientdata.csv")

# %%
train_InP
# Out:
#            BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0       BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1       BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2       BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3       BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4       BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
# ...           ...       ...          ...         ...       ...
# 40469  BENE159167  CLM69886   2009-09-28  2009-10-02  PRV53671
# 40470  BENE159175  CLM74504   2009-11-03  2009-11-06  PRV54981
# 40471  BENE159177  CLM76485   2009-11-18  2009-11-22  PRV56588
# 40472  BENE159177  CLM79949   2009-12-17  2009-12-18  PRV56575
# 40473  BENE159188  CLM69948   2009-09-28  2009-10-06  PRV54765
#
#        InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                       26000          PHY390922                NaN
# 1                        5000          PHY318495          PHY318495
# ...

# %%
train_OutP = pd.read_csv(r"C:\Users\rkpra\Downloads\Healthcare provider fraud detection\archive\Train_Outpatientdata.csv")

# %%
train_OutP
# Out:
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0        BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1        BENE11003  CLM189947   2009-02-12  2009-02-12  PRV57610
# 2        BENE11003  CLM438021   2009-06-27  2009-06-27  PRV57595
# 3        BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 4        BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
# ...            ...        ...          ...         ...       ...
# 517732  BENE159198  CLM510792   2009-08-06  2009-08-06  PRV53699
# 517733  BENE159198  CLM551294   2009-08-29  2009-08-29  PRV53702
# 517734  BENE159198  CLM596444   2009-09-24  2009-09-24  PRV53676
# 517735  BENE159198  CLM636992   2009-10-18  2009-10-18  PRV53689
# 517736  BENE159198  CLM686139   2009-11-17  2009-11-18  PRV53689
#
#         InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                           30          PHY326117                NaN
# ...

# %%
train_InP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40474 entries, 0 to 40473
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   BeneID                  40474 non-null  object
#  1   ClaimID                 40474 non-null  object
#  2   ClaimStartDt            40474 non-null  object
#  3   ClaimEndDt              40474 non-null  object
#  4   Provider                40474 non-null  object
#  5   InscClaimAmtReimbursed  40474 non-null  int64
#  6   AttendingPhysician      40362 non-null  object
#  7   OperatingPhysician      23830 non-null  object
#  8   OtherPhysician          4690 non-null   object
#  9   AdmissionDt             40474 non-null  object
#  10  ClmAdmitDiagnosisCode   40474 non-null  object
#  11  DeductibleAmtPaid       39575 non-null  float64
#  12  DischargeDt             40474 non-null  object
#  13  DiagnosisGroupCode      40474 non-null  object
# ...

# %%
train_OutP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517737 entries, 0 to 517736
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   BeneID                  517737 non-null  object
#  1   ClaimID                 517737 non-null  object
#  2   ClaimStartDt            517737 non-null  object
#  3   ClaimEndDt              517737 non-null  object
#  4   Provider                517737 non-null  object
#  5   InscClaimAmtReimbursed  517737 non-null  int64
#  6   AttendingPhysician      516341 non-null  object
#  7   OperatingPhysician      90617 non-null   object
#  8   OtherPhysician          195046 non-null  object
#  9   ClmDiagnosisCode_1      507284 non-null  object
#  10  ClmDiagnosisCode_2      322357 non-null  object
#  11  ClmDiagnosisCode_3      203257 non-null  object
#  12  ClmDiagnosisCode_4      125596 non-null  object
#  13  ClmDiagnosisCode_5      74344 non-null   object
# ...

# %%
InP_columns = set(train_InP.columns)
OutP_columns = set(train_OutP.columns)

# %%
InP_columns.intersection(OutP_columns)
# Out:
# {'AttendingPhysician',
#  'BeneID',
#  'ClaimEndDt',
#  'ClaimID',
#  'ClaimStartDt',
#  'ClmAdmitDiagnosisCode',
#  'ClmDiagnosisCode_1',
#  'ClmDiagnosisCode_10',
#  'ClmDiagnosisCode_2',
#  'ClmDiagnosisCode_3',
#  'ClmDiagnosisCode_4',
#  'ClmDiagnosisCode_5',
#  'ClmDiagnosisCode_6',
#  'ClmDiagnosisCode_7',
#  'ClmDiagnosisCode_8',
#  'ClmDiagnosisCode_9',
#  'ClmProcedureCode_1',
#  'ClmProcedureCode_2',
#  'ClmProcedureCode_3',
#  'ClmProcedureCode_4',
#  'ClmProcedureCode_5',
#  'ClmProcedureCode_6',
#  'DeductibleAmtPaid',
#  'InscClaimAmtReimbursed',
#  'OperatingPhysician',
#  'OtherPhysician',
#  'Provider'}

# %%
Addition_Info = list(InP_columns - OutP_columns)

# %%
OutP_columns - InP_columns
# Out:
# set()

# %%
train_OutP[Addition_Info] = ''

# %%
set(train_InP.columns) - set(train_OutP.columns)
# Out:
# set()

# %%
set(train_OutP.columns) - set(train_InP.columns)
# Out:
# set()

# %%
train_InP.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
#        'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6'],
#       dtype='object')

# %%
train_OutP.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2',
#        'ClmDiagnosisCode_3', 'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5',
#        'ClmDiagnosisCode_6', 'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8',
#        'ClmDiagnosisCode_9', 'ClmDiagnosisCode_10', 'ClmProcedureCode_1',
#        'ClmProcedureCode_2', 'ClmProcedureCode_3', 'ClmProcedureCode_4',
#        'ClmProcedureCode_5', 'ClmProcedureCode_6', 'DeductibleAmtPaid',
#        'ClmAdmitDiagnosisCode', 'AdmissionDt', 'DischargeDt',
#        'DiagnosisGroupCode'],
#       dtype='object')

# %%
train_OutP = train_OutP[train_InP.columns]

# %%
train_OutP.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
#        'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6'],
#       dtype='object')

# %%
full_data = train_InP.append(train_OutP)
full_data
# Out:
# C:\Users\rkpra\AppData\Local\Temp\ipykernel_7008\3002967171.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   full_data = train_InP.append(train_OutP)
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0        BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1        BENE11001   CLM66048   2009-08-31  2009-09-02  PRV55907
# 2        BENE11001   CLM68358   2009-09-17  2009-09-20  PRV56046
# 3        BENE11011   CLM38412   2009-02-14  2009-02-22  PRV52405
# 4        BENE11014   CLM63689   2009-08-13  2009-08-30  PRV56614
# ...            ...        ...          ...         ...       ...
# 517732  BENE159198  CLM510792   2009-08-06  2009-08-06  PRV53699
# 517733  BENE159198  CLM551294   2009-08-29  2009-08-29  PRV53702
# 517734  BENE159198  CLM596444   2009-09-24  2009-09-24  PRV53676
# 517735  BENE159198  CLM636992   2009-10-18  2009-10-18  PRV53689
# ...

# %% [markdown]
# ## EDA

# %%
train_InP.shape
# Out:
# (40474, 30)

# %%
train_OutP.shape
# Out:
# (517737, 30)

# %%
full_date["BeneID"].nunique()
# Out:
# 138556

# %%
full_date["ClaimID"].nunique()
# Out:
# 558211

# %%
full_date["InscClaimAmtReimbursed"].nunique()
# Out:
# 438

# %% [markdown]
# ## Date time Convert for ClaimStartDt & ClaimEndDt

# %%
full_data["ClaimStartDt"] = pd.to_datetime(full_data["ClaimStartDt"])

# %%
full_data["ClaimStartDt"]
# Out:
# 0        2009-04-12
# 1        2009-08-31
# 2        2009-09-17
# 3        2009-02-14
# 4        2009-01-18
#             ...
# 558206   2009-08-06
# 558207   2009-08-29
# 558208   2009-09-24
# 558209   2009-10-18
# 558210   2009-11-17
# Name: ClaimStartDt, Length: 558211, dtype: datetime64[ns]

# %%
full_data["ClaimEndDt"] = pd.to_datetime(full_data["ClaimEndDt"])

# %%
full_data["ClaimEndDt"]
# Out:
# 0        2009-04-18
# 1        2009-09-02
# 2        2009-09-20
# 3        2009-02-22
# 4        2009-01-18
#             ...
# 558206   2009-08-06
# 558207   2009-08-29
# 558208   2009-09-24
# 558209   2009-10-18
# 558210   2009-11-18
# Name: ClaimEndDt, Length: 558211, dtype: datetime64[ns]

# %%
full_data["claims_duration"] = (full_data["ClaimEndDt"] - full_data["ClaimStartDt"]).dt.days

# %%
full_data["claims_duration"]
# Out:
# 0         6
# 1         2
# 2         3
# 3         8
# 4         0
#          ..
# 558206    0
# 558207    0
# 558208    0
# 558209    0
# 558210    1
# Name: claims_duration, Length: 558211, dtype: int64

# %%
beneID_unique = pd.DataFrame(full_data.groupby("Provider")["BeneID"].nunique()).reset_index()
beneID_unique.sort_values("BeneID", inplace=True, ascending=False)
beneID_unique.reset_index(inplace = True, drop = True)
beneID_unique
# Out:
#       Provider  BeneID
# 0     PRV51459    2857
# 1     PRV55215    2638
# 2     PRV53797    2020
# 3     PRV52019    1734
# 4     PRV51574    1715
# ...        ...     ...
# 5405  PRV56891       1
# 5406  PRV52757       1
# 5407  PRV57371       1
# 5408  PRV55622       1
# 5409  PRV55384       1
#
# [5410 rows x 2 columns]

# %%
full_data.groupby("Provider").count()
# Out:
#           BeneID  ClaimID  ClaimStartDt  ClaimEndDt  InscClaimAmtReimbursed  \
# Provider
# PRV51001      25       25            25          25                      25
# PRV51003     132      132           132         132                     132
# PRV51004     149      149           149         149                     149
# PRV51005    1165     1165          1165        1165                    1165
# PRV51007      72       72            72          72                      72
# ...          ...      ...           ...         ...                     ...
# PRV57759      28       28            28          28                      28
# PRV57760      22       22            22          22                      22
# PRV57761      82       82            82          82                      82
# PRV57762       1        1             1           1                       1
# PRV57763     118      118           118         118                     118
#
# ...

# %%
claim_ClaimAmtReimbursed = full_data.groupby("Provider")["InscClaimAmtReimbursed"].mean().reset_index()
claim_ClaimAmtReimbursed.sort_values("InscClaimAmtReimbursed", inplace = True , ascending = False)
claim_ClaimAmtReimbursed.reset_index(inplace = True, drop = True)
claim_ClaimAmtReimbursed
# Out:
#       Provider  InscClaimAmtReimbursed
# 0     PRV52537                 57000.0
# 1     PRV57080                 57000.0
# 2     PRV57399                 57000.0
# 3     PRV53033                 37500.0
# 4     PRV52804                 36000.0
# ...        ...                     ...
# 5405  PRV52957                     0.0
# 5406  PRV53725                     0.0
# 5407  PRV57396                     0.0
# 5408  PRV56988                     0.0
# 5409  PRV56540                     0.0
#
# [5410 rows x 2 columns]

# %%
Ben_claim_amnt =full_data.groupby("BeneID").agg({"InscClaimAmtReimbursed":"mean"}).reset_index()
Ben_claim_amnt.sort_values("InscClaimAmtReimbursed", inplace = True, ascending = False)
Ben_claim_amnt.reset_index(inplace = True , drop = True)
Ben_claim_amnt
# Out:
#             BeneID  InscClaimAmtReimbursed
# 0       BENE129919                101000.0
# 1        BENE77765                 93840.0
# 2       BENE148978                 92000.0
# 3       BENE130861                 91080.0
# 4       BENE155688                 86750.0
# ...            ...                     ...
# 138551   BENE68266                     0.0
# 138552   BENE28337                     0.0
# 138553  BENE113220                     0.0
# 138554   BENE57674                     0.0
# 138555   BENE43574                     0.0
#
# [138556 rows x 2 columns]

# %%
provider_AttPhysician = full_data.groupby("Provider").agg({"AttendingPhysician":"count"})
provider_AttPhysician.sort_values("AttendingPhysician" , inplace = True, ascending = False)
provider_AttPhysician.reset_index(inplace = True)
provider_AttPhysician
# Out:
#       Provider  AttendingPhysician
# 0     PRV51459                8207
# 1     PRV53797                4726
# 2     PRV51574                4434
# 3     PRV53918                3582
# 4     PRV54895                3426
# ...        ...                 ...
# 5405  PRV56774                   1
# 5406  PRV57386                   1
# 5407  PRV56969                   1
# 5408  PRV57371                   1
# 5409  PRV57396                   1
#
# [5410 rows x 2 columns]

# %%
provider_AttPhysician = pd.DataFrame(full_data.groupby("Provider")["AttendingPhysician"].nunique())
provider_AttPhysician.sort_values("AttendingPhysician", inplace = True, ascending = False)
provider_AttPhysician.reset_index(inplace = True )
provider_AttPhysician
# Out:
#       Provider  AttendingPhysician
# 0     PRV52019                 643
# 1     PRV55215                 544
# 2     PRV55510                 418
# 3     PRV57173                 305
# 4     PRV56268                 299
# ...        ...                 ...
# 5405  PRV55974                   1
# 5406  PRV51831                   1
# 5407  PRV52789                   1
# 5408  PRV52431                   1
# 5409  PRV57763                   1
#
# [5410 rows x 2 columns]

# %%
provider_claim_count= pd.DataFrame(full_data.groupby("Provider")["ClaimID"].nunique())
provider_claim_count.sort_values("ClaimID", inplace = True, ascending = False)
provider_claim_count.reset_index(inplace = True)
provider_claim_count
# Out:
#       Provider  ClaimID
# 0     PRV51459     8240
# 1     PRV53797     4739
# 2     PRV51574     4444
# 3     PRV53918     3588
# 4     PRV54895     3436
# ...        ...      ...
# 5405  PRV56373        1
# 5406  PRV52221        1
# 5407  PRV55578        1
# 5408  PRV56377        1
# 5409  PRV52899        1
#
# [5410 rows x 2 columns]

# %%
Beneid_unique = pd.DataFrame(full_data.groupby("BeneID")["ClaimID"].nunique())
Beneid_unique.sort_values("ClaimID",inplace = True, ascending = False)
Beneid_unique.reset_index(inplace = True)
Beneid_unique
# Out:
#             BeneID  ClaimID
# 0       BENE118316       29
# 1        BENE42721       29
# 2        BENE59303       29
# 3        BENE44241       28
# 4        BENE80977       28
# ...            ...      ...
# 138551   BENE60176        1
# 138552  BENE138920        1
# 138553   BENE60182        1
# 138554   BENE60183        1
# 138555   BENE63786        1
#
# [138556 rows x 2 columns]

# %%
provider_clam_diagonis = pd.DataFrame(full_data.groupby("Provider")["ClmAdmitDiagnosisCode"].nunique())
provider_clam_diagonis.sort_values("ClmAdmitDiagnosisCode", inplace = True , ascending = False)
provider_clam_diagonis.reset_index(inplace = True)
provider_clam_diagonis
# Out:
#       Provider  ClmAdmitDiagnosisCode
# 0     PRV51459                    582
# 1     PRV53797                    401
# 2     PRV51574                    399
# 3     PRV55215                    375
# 4     PRV54895                    359
# ...        ...                    ...
# 5405  PRV53642                      0
# 5406  PRV51621                      0
# 5407  PRV52453                      0
# 5408  PRV53645                      0
# 5409  PRV54177                      0
#
# [5410 rows x 2 columns]

# %%
ben_clm_count= pd.DataFrame(full_data.groupby("BeneID")["ClaimID"].nunique())
ben_clm_count.sort_values("ClaimID", inplace = True, ascending = False)
ben_clm_count.reset_index(inplace = True)
ben_clm_count
# Out:
#             BeneID  ClaimID
# 0       BENE118316       29
# 1        BENE42721       29
# 2        BENE59303       29
# 3        BENE44241       28
# 4        BENE80977       28
# ...            ...      ...
# 138551   BENE60176        1
# 138552  BENE138920        1
# 138553   BENE60182        1
# 138554   BENE60183        1
# 138555   BENE63786        1
#
# [138556 rows x 2 columns]

# %%
attenphysician_provider = pd.DataFrame(full_data.groupby("AttendingPhysician")["Provider"].count())
attenphysician_provider.sort_values("Provider", inplace = True , ascending = False)
attenphysician_provider.reset_index(inplace = True)
attenphysician_provider
# Out:
#       AttendingPhysician  Provider
# 0              PHY330576      2534
# 1              PHY350277      1628
# 2              PHY412132      1321
# 3              PHY423534      1223
# 4              PHY314027      1200
# ...                  ...       ...
# 82058          PHY385586         1
# 82059          PHY385588         1
# 82060          PHY385590         1
# 82061          PHY336444         1
# 82062          PHY393695         1
#
# [82063 rows x 2 columns]

# %%
provider_data = beneID_unique.merge(claim_ClaimAmtReimbursed,how="inner",on="Provider")
provider_data.rename(columns={"BeneID":"Beneficiary_count","InscClaimAmtReimbursed":"Mean_Calim_reimbused"},inplace=True)
provider_data
# Out:
#       Provider  Beneficiary_count  Mean_Calim_reimbused
# 0     PRV51459               2857            281.782767
# 1     PRV55215               2638            673.315650
# 2     PRV53797               2020            275.079131
# 3     PRV52019               1734           3057.649159
# 4     PRV51574               1715            288.436094
# ...        ...                ...                   ...
# 5405  PRV56891                  1             10.000000
# 5406  PRV52757                  1             50.000000
# 5407  PRV57371                  1             70.000000
# 5408  PRV55622                  1           1500.000000
# 5409  PRV55384                  1             30.000000
#
# [5410 rows x 3 columns]

# %%
provider_data = provider_data.merge(provider_AttPhysician,how="inner",on="Provider")
provider_data.rename(columns={"AttendingPhysician":"Count_AttendingPhysician"},inplace=True)
provider_data
# Out:
#       Provider  Beneficiary_count  Mean_Calim_reimbused  \
# 0     PRV51459               2857            281.782767
# 1     PRV55215               2638            673.315650
# 2     PRV53797               2020            275.079131
# 3     PRV52019               1734           3057.649159
# 4     PRV51574               1715            288.436094
# ...        ...                ...                   ...
# 5405  PRV56891                  1             10.000000
# 5406  PRV52757                  1             50.000000
# 5407  PRV57371                  1             70.000000
# 5408  PRV55622                  1           1500.000000
# 5409  PRV55384                  1             30.000000
#
#       Count_AttendingPhysician
# 0                         8207
# 1                         3388
# 2                         4726
# 3                         1956
# 4                         4434
# ...                        ...
# 5405                         1
# 5406                         1
# ...

# %%
provider_data.columns
# Out:
# Index(['Provider', 'Beneficiary_count', 'Mean_Calim_reimbused',
#        'Count_AttendingPhysician'],
#       dtype='object')

# %%
provider_data.drop(columns=['ClaimID_x', 'ClaimID_y', 'ClaimID_x',
       'ClaimID_y'],inplace=True)

# %%
provider_data = provider_data.merge(provider_claim_count,how="inner",on="Provider")

# %%
provider_data.rename(columns={"ClaimID":"Beneficiary_claim_count"}, inplace = True)
provider_data
# Out:
#       Provider  Beneficiary_count  Mean_Calim_reimbused  \
# 0     PRV51459               2857            281.782767
# 1     PRV55215               2638            673.315650
# 2     PRV53797               2020            275.079131
# 3     PRV52019               1734           3057.649159
# 4     PRV51574               1715            288.436094
# ...        ...                ...                   ...
# 5405  PRV56891                  1             10.000000
# 5406  PRV52757                  1             50.000000
# 5407  PRV57371                  1             70.000000
# 5408  PRV55622                  1           1500.000000
# 5409  PRV55384                  1             30.000000
#
#       Count_AttendingPhysician  Beneficiary_claim_count
# 0                         8207                     8240
# 1                         3388                     3393
# 2                         4726                     4739
# 3                         1956                     1961
# ...

# %%
provider_data =provider_data.merge(provider_clam_diagonis, how="inner", on="Provider")

# %%
provider_data.rename(columns = {"ClmAdmitDiagnosisCode":"Claim_Admit_Diagnosis_count"}, inplace = True)
provider_data
# Out:
#       Provider  Beneficiary_count  Mean_Calim_reimbused  \
# 0     PRV51459               2857            281.782767
# 1     PRV55215               2638            673.315650
# 2     PRV53797               2020            275.079131
# 3     PRV52019               1734           3057.649159
# 4     PRV51574               1715            288.436094
# ...        ...                ...                   ...
# 5405  PRV56891                  1             10.000000
# 5406  PRV52757                  1             50.000000
# 5407  PRV57371                  1             70.000000
# 5408  PRV55622                  1           1500.000000
# 5409  PRV55384                  1             30.000000
#
#       Count_AttendingPhysician  Beneficiary_claim_count  \
# 0                         8207                     8240
# 1                         3388                     3393
# 2                         4726                     4739
# 3                         1956                     1961
# ...

# %%
attenphysician_provider
# Out:
#       AttendingPhysician  Provider
# 0              PHY330576      2534
# 1              PHY350277      1628
# 2              PHY412132      1321
# 3              PHY423534      1223
# 4              PHY314027      1200
# ...                  ...       ...
# 82058          PHY385586         1
# 82059          PHY385588         1
# 82060          PHY385590         1
# 82061          PHY336444         1
# 82062          PHY393695         1
#
# [82063 rows x 2 columns]

# %%
Train_Beneficial
# Out:
#             BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  \
# 0        BENE11001  1943-01-01  NaN       1     1                     0
# 1        BENE11002  1936-09-01  NaN       2     1                     0
# 2        BENE11003  1936-08-01  NaN       1     1                     0
# 3        BENE11004  1922-07-01  NaN       1     1                     0
# 4        BENE11005  1935-09-01  NaN       1     1                     0
# ...            ...         ...  ...     ...   ...                   ...
# 138551  BENE159194  1939-07-01  NaN       1     1                     0
# 138552  BENE159195  1938-12-01  NaN       2     1                     0
# 138553  BENE159196  1916-06-01  NaN       2     1                     0
# 138554  BENE159197  1930-01-01  NaN       1     1                     0
# 138555  BENE159198  1952-04-01  NaN       2     1                     0
#
#         State  County  NoOfMonths_PartACov  NoOfMonths_PartBCov  \
# ...

# %%
full_data
# Out:
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0        BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1        BENE11001   CLM66048   2009-08-31  2009-09-02  PRV55907
# 2        BENE11001   CLM68358   2009-09-17  2009-09-20  PRV56046
# 3        BENE11011   CLM38412   2009-02-14  2009-02-22  PRV52405
# 4        BENE11014   CLM63689   2009-08-13  2009-08-30  PRV56614
# ...            ...        ...          ...         ...       ...
# 517732  BENE159198  CLM510792   2009-08-06  2009-08-06  PRV53699
# 517733  BENE159198  CLM551294   2009-08-29  2009-08-29  PRV53702
# 517734  BENE159198  CLM596444   2009-09-24  2009-09-24  PRV53676
# 517735  BENE159198  CLM636992   2009-10-18  2009-10-18  PRV53689
# 517736  BENE159198  CLM686139   2009-11-17  2009-11-18  PRV53689
#
#         InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                        26000          PHY390922                NaN
# ...

# %%
full_data = full_data.merge(Train_Beneficial,how="inner",on="BeneID")

# %%
full_data
# Out:
#             BeneID    ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 0        BENE11001   CLM46614   2009-04-12 2009-04-18  PRV55912
# 1        BENE11001   CLM66048   2009-08-31 2009-09-02  PRV55907
# 2        BENE11001   CLM68358   2009-09-17 2009-09-20  PRV56046
# 3        BENE11011   CLM38412   2009-02-14 2009-02-22  PRV52405
# 4        BENE11011  CLM144521   2009-01-18 2009-01-18  PRV52314
# ...            ...        ...          ...        ...       ...
# 558206  BENE159198  CLM510792   2009-08-06 2009-08-06  PRV53699
# 558207  BENE159198  CLM551294   2009-08-29 2009-08-29  PRV53702
# 558208  BENE159198  CLM596444   2009-09-24 2009-09-24  PRV53676
# 558209  BENE159198  CLM636992   2009-10-18 2009-10-18  PRV53689
# 558210  BENE159198  CLM686139   2009-11-17 2009-11-18  PRV53689
#
#         InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                        26000          PHY390922                NaN
# ...

# %%
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='claims_duration', ylabel='count'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# setting the dimensions of the plot
fig, ax = plt.subplots(figsize=(10,5))
 
# drawing the plot
sns.countplot(full_data.claims_duration, ax=ax)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='claims_duration', ylabel='count'>

# %%
full_data["DOD"].unique()
# Out:
# array([nan, '2009-05-01', '2009-08-01', '2009-07-01', '2009-06-01',
#        '2009-12-01', '2009-11-01', '2009-04-01', '2009-10-01',
#        '2009-03-01', '2009-09-01', '2009-02-01'], dtype=object)

# %%
full_data["ClaimEndDt"] = pd.to_datetime(full_data["ClaimEndDt"])

# %%
full_data["DOB"] = pd.to_datetime(full_data["DOB"])

# %%
full_data["DOD"] = pd.to_datetime(full_data["DOD"])

# %%
full_data["DOD"] - full_data["DOB"]

# %%
full_data["DOD"]
# Out:
# 0        2009-02-01
# 1        2009-02-01
# 2        2009-02-01
# 3        2009-02-01
# 4        2009-02-01
#             ...
# 558206   2009-02-01
# 558207   2009-02-01
# 558208   2009-02-01
# 558209   2009-02-01
# 558210   2009-02-01
# Name: DOD, Length: 558211, dtype: datetime64[ns]

# %%
full_data["DOD"].sort_values()
# Out:
# 0        2009-02-01
# 371509   2009-02-01
# 371508   2009-02-01
# 371507   2009-02-01
# 371506   2009-02-01
#             ...
# 405902   2009-12-01
# 289171   2009-12-01
# 289170   2009-12-01
# 113567   2009-12-01
# 95867    2009-12-01
# Name: DOD, Length: 558211, dtype: datetime64[ns]

# %%
full_data["DOD"] = full_data["DOD"].fillna("2009-02-01")

# %%
(full_data["DOD"] - full_data["DOB"]).dt.days
# Out:
# 0         24138
# 1         24138
# 2         24138
# 3         34671
# 4         34671
#           ...
# 558206    20760
# 558207    20760
# 558208    20760
# 558209    20760
# 558210    20760
# Length: 558211, dtype: int64

# %%
((full_data["DOD"] - full_data["DOB"]).dt.days/365).astype(int)
# Out:
# 0         66
# 1         66
# 2         66
# 3         94
# 4         94
#           ..
# 558206    56
# 558207    56
# 558208    56
# 558209    56
# 558210    56
# Length: 558211, dtype: int32

# %%
full_data["age"] = (full_data["DOD"].dt.year)-(full_data["DOB"].dt.year)

# %%
full_data["claims_duration"] = (full_data["ClaimEndDt"] - full_data["ClaimStartDt"]).dt.days

# %%
full_data = full_data.merge(df,how="inner", on = "Provider")

# %%
full_data
# Out:
#             BeneID    ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 0        BENE11001   CLM46614   2009-04-12 2009-04-18  PRV55912
# 1        BENE16973  CLM565430   2009-09-06 2009-09-06  PRV55912
# 2        BENE17521   CLM34721   2009-01-20 2009-02-01  PRV55912
# 3        BENE21718   CLM72336   2009-10-17 2009-11-04  PRV55912
# 4        BENE22934   CLM73394   2009-10-25 2009-10-29  PRV55912
# ...            ...        ...          ...        ...       ...
# 558206  BENE154147  CLM394122   2009-06-02 2009-06-04  PRV54050
# 558207  BENE154687  CLM184358   2009-02-08 2009-02-08  PRV54302
# 558208  BENE157378  CLM460770   2009-07-09 2009-07-29  PRV51577
# 558209  BENE158295  CLM306999   2009-04-16 2009-04-16  PRV53083
# 558210  BENE158736  CLM589654   2009-09-20 2009-09-20  PRV56377
#
#         InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                        26000          PHY390922                NaN
# ...

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 558211 entries, 0 to 558210
# Data columns (total 57 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   BeneID                           558211 non-null  object
#  1   ClaimID                          558211 non-null  object
#  2   ClaimStartDt                     558211 non-null  datetime64[ns]
#  3   ClaimEndDt                       558211 non-null  datetime64[ns]
#  4   Provider                         558211 non-null  object
#  5   InscClaimAmtReimbursed           558211 non-null  int64
#  6   AttendingPhysician               556703 non-null  object
#  7   OperatingPhysician               114447 non-null  object
#  8   OtherPhysician                   199736 non-null  object
#  9   AdmissionDt                      558211 non-null  object
#  10  ClmAdmitDiagnosisCode            145899 non-null  object
# ...

# %%
full_data["PotentialFraud"].value_counts()*100/len(full_data)
# Out:
# No     61.878931
# Yes    38.121069
# Name: PotentialFraud, dtype: float64

# %%
x=full_data.drop(columns = "PotentialFraud")

# %%
x
# Out:
#             BeneID    ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 0        BENE11001   CLM46614   2009-04-12 2009-04-18  PRV55912
# 1        BENE16973  CLM565430   2009-09-06 2009-09-06  PRV55912
# 2        BENE17521   CLM34721   2009-01-20 2009-02-01  PRV55912
# 3        BENE21718   CLM72336   2009-10-17 2009-11-04  PRV55912
# 4        BENE22934   CLM73394   2009-10-25 2009-10-29  PRV55912
# ...            ...        ...          ...        ...       ...
# 558206  BENE154147  CLM394122   2009-06-02 2009-06-04  PRV54050
# 558207  BENE154687  CLM184358   2009-02-08 2009-02-08  PRV54302
# 558208  BENE157378  CLM460770   2009-07-09 2009-07-29  PRV51577
# 558209  BENE158295  CLM306999   2009-04-16 2009-04-16  PRV53083
# 558210  BENE158736  CLM589654   2009-09-20 2009-09-20  PRV56377
#
#         InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                        26000          PHY390922                NaN
# ...

# %%
y = full_data["PotentialFraud"]

# %%
y
# Out:
# 0         Yes
# 1         Yes
# 2         Yes
# 3         Yes
# 4         Yes
#          ...
# 558206     No
# 558207     No
# 558208     No
# 558209     No
# 558210     No
# Name: PotentialFraud, Length: 558211, dtype: object

# %%
full_data.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
#        'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6', 'DOB', 'DOD', 'Gender', 'Race',
#        'RenalDiseaseIndicator', 'State', 'County', 'NoOfMonths_PartACov',
#        'NoOfMonths_PartBCov', 'ChronicCond_Alzheimer',
#        'ChronicCond_Heartfailure', 'ChronicCond_KidneyDisease',
#        'ChronicCond_Cancer', 'ChronicCond_ObstrPulmonary',
# ...

# %%
full_data = full_data[['InscClaimAmtReimbursed',
       'Gender', 'Race',
     'State', 'County', 'NoOfMonths_PartACov',
       'NoOfMonths_PartBCov', 'ChronicCond_Alzheimer',
       'ChronicCond_Heartfailure', 'ChronicCond_KidneyDisease',
       'ChronicCond_Cancer', 'ChronicCond_ObstrPulmonary',
       'ChronicCond_Depression', 'ChronicCond_Diabetes',
       'ChronicCond_IschemicHeart', 'ChronicCond_Osteoporasis',
       'ChronicCond_rheumatoidarthritis', 'ChronicCond_stroke',
       'IPAnnualReimbursementAmt', 'IPAnnualDeductibleAmt',
       'OPAnnualReimbursementAmt', 'OPAnnualDeductibleAmt', 'claims_duration',
       'age',]]

full_data
# Out:
#         InscClaimAmtReimbursed  Gender  Race  State  County  \
# 0                        26000       1     1     39     230
# 1                           50       1     1     39     310
# 2                        19000       2     1     39     230
# 3                        17000       1     1     39     600
# 4                        13000       2     1     39     280
# ...                        ...     ...   ...    ...     ...
# 558206                     500       2     1     23     400
# 558207                    3300       1     2     25     150
# 558208                    2100       2     1      5     200
# 558209                      10       2     1     16     490
# 558210                      60       2     1     43     170
#
#         NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# 0                        12                   12                      1
# 1                        12                   12                      1
# ...

# %%
full_data.isnull().sum()
# Out:
# InscClaimAmtReimbursed             0
# DiagnosisGroupCode                 0
# Gender                             0
# Race                               0
# RenalDiseaseIndicator              0
# State                              0
# County                             0
# NoOfMonths_PartACov                0
# NoOfMonths_PartBCov                0
# ChronicCond_Alzheimer              0
# ChronicCond_Heartfailure           0
# ChronicCond_KidneyDisease          0
# ChronicCond_Cancer                 0
# ChronicCond_ObstrPulmonary         0
# ChronicCond_Depression             0
# ChronicCond_Diabetes               0
# ChronicCond_IschemicHeart          0
# ChronicCond_Osteoporasis           0
# ChronicCond_rheumatoidarthritis    0
# ChronicCond_stroke                 0
# IPAnnualReimbursementAmt           0
# IPAnnualDeductibleAmt              0
# OPAnnualReimbursementAmt           0
# OPAnnualDeductibleAmt              0
# claims_duration                    0
# ...

# %%
uniform_data = np.random.rand(10,10)
ax = sns.heatmap(uniform_data,annot=True)

# %%
plt.figure(figsize=(10,10))
heat_map = sns.heatmap( full_data, linewidth = 1 , annot = True)
plt.title( "HeatMap using Seaborn Method" )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [495], in <cell line: 2>()
#       1 plt.figure(figsize=(10,10))
# ----> 2 heat_map = sns.heatmap( full_data, linewidth = 1 , annot = True)
#       3 plt.title( "HeatMap using Seaborn Method" )
#       4 plt.show()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
##multivariate analysis heatmap
corrmat = full_data.corr()
top_corr_feature= corrmat.index
plt.figure(figsize=(40,40))
g= sns.heatmap(full_data[top_corr_feature].corr(),annot=True,cmap='RdYlGn')
